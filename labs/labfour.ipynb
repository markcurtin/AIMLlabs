# %% [markdown]
# Training a Decision Tree Classifier
# Get the iris dataset and train a classifier using a decision tree. Use scikit-
# learn’s DecisionTreeClassifier.
# Note: use the dataset provided by sklearn datasets (check documentation)
# #make a new observation and predict observation’s class
# observation = [[5, 4, 3, 2]]
# # A line of code missing here
# ?
# #view predicted class probabilities of the observation
# model.predict_proba(observation)
# Finally, check the documentation of pydotplus library and write the
# visualisation (‘tree’) in PNG format.
