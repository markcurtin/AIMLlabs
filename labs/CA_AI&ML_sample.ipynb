# %% [markdown]
# ## Artificial Intelligence and Machine Learning Modelling
# ### Sample Continuous assessment
#
# **This is only a sample CA, the real CA may be slight different.**

# %% [markdown]
# You can use the class notes, labs and the following links:
# - https://pandas.pydata.org/docs/
# - https://scikit-learn.org/0.21/documentation.html
# - https://seaborn.pydata.org/api.html
# - https://numpy.org/doc/2.2/
#
# You also can use search engine to solve your coding problems **without** *AI model*.
#
# **GenAI strictly cannot be used for this CA.** Otherwise, you would need to have a interview about this CA if we have doubts about your CA.

# %% [markdown]
# ## About the dataset
#
# The database was created with records of absenteeism at work from July 2007 to July 2010 at a courier company in Brazil.
# 1. Individual identification (ID)
#
# 2. Reason for absence (ICD).
#
# Absences attested by the International Code of Diseases (ICD) stratified into 21 categories (I to XXI) as follows:
#
#             I Certain infectious and parasitic diseases
#
#             II Neoplasms
#
#             III Diseases of the blood and blood-forming organs and certain disorders involving the immune mechanism
#
#             IV Endocrine, nutritional and metabolic diseases
#
#             V Mental and behavioural disorders
#
#             VI Diseases of the nervous system
#
#             VII Diseases of the eye and adnexa
#
#             VIII Diseases of the ear and mastoid process
#
#             IX Diseases of the circulatory system
#
#             X Diseases of the respiratory system
#
#             XI Diseases of the digestive system
#
#             XII Diseases of the skin and subcutaneous tissue
#
#             XIII Diseases of the musculoskeletal system and connective tissue
#
#             XIV Diseases of the genitourinary system
#
#             XV Pregnancy, childbirth and the puerperium
#
#             XVI Certain conditions originating in the perinatal period
#
#             XVII Congenital malformations, deformations and chromosomal abnormalities
#
#             XVIII Symptoms, signs and abnormal clinical and laboratory findings, not elsewhere classified
#
#             XIX Injury, poisoning and certain other consequences of external causes
#
#             XX External causes of morbidity and mortality
#
#             XXI Factors influencing health status and contact with health services.
#
# 3. Month of absence
#
# 4. Day of the week (Monday (2), Tuesday (3), Wednesday (4), Thursday (5), Friday (6))
#
# 5. Seasons (4 variants)
#
# 6. Transportation expense (euro)
#
# 7. Distance from Residence to Work (Kilometers, the company is located in a business park, thus there is no housing for a minimum of 1 KM)
#
# 8. Service time (years)
#
# 9. Age (minimum age is 17-18 to work in this company)
#
# 10. Workload Average
#
# 11. Hit target
#
# 12. Disciplinary failure (yes=1; no=0)
#
# 13. Education (high school (1), graduate (2), postgraduate (3), master and doctor (4))
#
# 14. Son (number of children)
#
# 15. Social drinker (yes=1; no=0)
#
# 16. Social smoker (yes=1; no=0)
#
# 17. Pet (number of pet)
#
# 18. Weight (KG)
#
# 19. Height (CM)
#
# 20. Body mass index
#
# 21. Absenteeism 0, 1 (**class/target**)

# %% [markdown]
# #### 1. Justification on selecting a supervised or unsupervised method (without coding)

# %% [markdown]
# **Write down your answers without coding**
#
# - 1.
# - 2.
# - 3.
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# loading csv file
data = pd.read_csv('Absenteeism_CA_sample.csv')
data.head()
# Out:
#    ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0   1                  22                 7                2        1
# 1   1                  23                 8                5        1
# 2   1                  26                12                4        4
# 3   1                   7                 4                6        3
# 4   1                  13                 6                6        3
#
#    Transportation expense  Distance from Residence to Work  Service time  Age  \
# 0                     235                               11            14   37
# 1                     235                               11            14   37
# 2                     235                               11            14   37
# 3                     235                               11            14   12
# 4                     235                               11            14   12
#
#    Work load Average/day   ...  Disciplinary failure  Education  Son  \
# ...

# %%
# Basic information about the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 740 entries, 0 to 739
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ID                               740 non-null    int64
#  1   Reason for absence               740 non-null    int64
#  2   Month of absence                 740 non-null    int64
#  3   Day of the week                  740 non-null    int64
#  4   Seasons                          740 non-null    int64
#  5   Transportation expense           740 non-null    int64
#  6   Distance from Residence to Work  740 non-null    int64
#  7   Service time                     740 non-null    int64
#  8   Age                              740 non-null    int64
#  9   Work load Average/day            740 non-null    int64
#  10  Hit target                       740 non-null    int64
#  11  Disciplinary failure             740 non-null    int64
# ...

# %% [markdown]
# #### 2. Initial analysis on the dataset with visualisations
#
# 1). Plot mutiple histgrams for numerical data using seaborn library, *e.g.*, sns.pairplot()
#
# 3). Plot a single histgram.
#
# 4). Plot a heatmap for correlation coefficients.

# %%
# write your code here

# %% [markdown]
# #### 3. Have a small discussion of what type of pre-processing is needed and why? (without coding)

# %% [markdown]
# **Write down your answers without coding**
#
# - 1.
# - 2.
# - 3.
# ...

# %% [markdown]
# #### 4 Pre-processing steps with explanation and justification
#
# Hints:
# 1. Statistic describe to undertand the dataset
# 2. Identify and address any missing data (missing data only for Reason for absence (ICD), distance from work and age)
# 3. Select the top attributes (using correlation coefficients to identify the number)
# 4. Normalization or standardization

# %% [markdown]
# #### 5. Feature engineering and justification (without coding)

# %% [markdown]
# **Write down your answers without coding**
#
# - 1.
# - 2.
# - 3.
# ...

# %% [markdown]
# #### 6. Modelling
# - Choose at least two ML models to train your data

# %%
from sklearn.model_selection import train_test_split
# sklearn 10FCV
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression

from sklearn import svm
from sklearn.neighbors import KNeighborsClassifier

from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

from sklearn.naive_bayes import GaussianNB, CategoricalNB

# %%
# write your code here

# %% [markdown]
# #### 7. Model evaluation
# - Explain how you evaluate your model.
# - Discusion the evaluation reults.
# - How the results could be improved.

# %%
# write your code here

# %% [markdown]
# ---
# ## END OF EXAM
# ---
#
# ### Before submitting:
# 1. ✓ Ensure all code cells have been run
# 2. ✓ Check all answers are complete
# 4. ✓ Save your notebook, rename it: **studentid_CA.ipynb**
# 5. ✓ Generate your notebook to corret HTML file.
#
#
# #### Good luck! Remember you would need to download **.ipynb** of the completed notebook and upload it to Brightspace!
